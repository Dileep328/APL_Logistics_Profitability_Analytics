# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %% [raw]
# load dataset

# %%
df = pd.read_csv("../data/raw/APL_Logistics.csv", encoding="latin1")

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %% [raw]
# Dataset Shape

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 180519
# Columns : 40

# %% [raw]
# First Look at Data

# %%
df.head()
# Out:
#     Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0  DEBIT                         6                              4
# 1  DEBIT                         4                              4
# 2  DEBIT                         4                              4
# 3  DEBIT                         6                              4
# 4  DEBIT                         6                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0             159.69              472.45     Late delivery
# 1              48.71              167.96  Shipping on time
# 2              87.36              181.99  Shipping on time
# 3             -41.89              175.99     Late delivery
# 4              10.00               40.00     Late delivery
#
#    Late_delivery_risk  Category Id     Category Name Customer City  \
# 0                   1            9  Cardio Equipment   Brownsville
# 1                   0           29     Shop By Sport     Littleton
# ...

# %%
df.tail()
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 180514  TRANSFER                         6                              4
# 180515     DEBIT                         2                              4
# 180516     DEBIT                         3                              4
# 180517   PAYMENT                         4                              4
# 180518      CASH                         1                              0
#
#         Benefit per order  Sales per customer   Delivery Status  \
# 180514            -107.96              161.87     Late delivery
# 180515            -126.56              172.66  Advance shipping
# 180516              91.25              314.64  Advance shipping
# 180517               1.53               10.91  Shipping on time
# 180518               9.79               34.98     Late delivery
#
#         Late_delivery_risk  Category Id     Category Name Customer City  \
# ...

# %%
df.sample(5)
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 96021   TRANSFER                         4                              4
# 8606       DEBIT                         5                              4
# 137132   PAYMENT                         6                              4
# 130114   PAYMENT                         2                              4
# 149188   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer    Delivery Status  \
# 96021               80.00              250.00  Shipping canceled
# 8606               111.63              237.50      Late delivery
# 137132              37.55              119.98      Late delivery
# 130114              57.32              163.77   Advance shipping
# 149188              11.81               28.80   Shipping on time
#
#         Late_delivery_risk  Category Id    Category Name Customer City  \
# ...

# %% [raw]
# Column Names

# %%
df.columns.tolist()
# Out:
# ['Type',
#  'Days for shipping (real)',
#  'Days for shipment (scheduled)',
#  'Benefit per order',
#  'Sales per customer',
#  'Delivery Status',
#  'Late_delivery_risk',
#  'Category Id',
#  'Category Name',
#  'Customer City',
#  'Customer Country',
#  'Customer Fname',
#  'Customer Id',
#  'Customer Lname',
#  'Customer Segment',
#  'Customer State',
#  'Customer Street',
#  'Customer Zipcode',
#  'Department Id',
#  'Department Name',
#  'Latitude',
#  'Longitude',
#  'Market',
#  'Order City',
#  'Order Country',
#  'Order Customer Id',
#  'Order Item Discount',
#  'Order Item Discount Rate',
#  'Order Item Product Price',
#  'Order Item Profit Ratio',
#  'Order Item Quantity',
#  'Sales',
#  'Order Item Total',
#  'Order Profit Per Order',
#  'Order Region',
#  'Order State',
#  'Order Status',
#  'Product Name',
#  'Product Price',
#  'Shipping Mode']

# %% [raw]
# Data Types

# %%
df.dtypes
# Out:
# Type                              object
# Days for shipping (real)           int64
# Days for shipment (scheduled)      int64
# Benefit per order                float64
# Sales per customer               float64
# Delivery Status                   object
# Late_delivery_risk                 int64
# Category Id                        int64
# Category Name                     object
# Customer City                     object
# Customer Country                  object
# Customer Fname                    object
# Customer Id                        int64
# Customer Lname                    object
# Customer Segment                  object
# Customer State                    object
# Customer Street                   object
# Customer Zipcode                 float64
# Department Id                      int64
# Department Name                   object
# Latitude                         float64
# Longitude                        float64
# Market                            object
# ...

# %% [raw]
# Missing Values Analysis

# %%
missing = df.isnull().sum()

missing[missing > 0]
# Out:
# Customer Lname      8
# Customer Zipcode    3
# dtype: int64

# %% [raw]
# percentage missing

# %%
missing_percent = (
    df.isnull().sum() /
    len(df)
) * 100

missing_percent.sort_values(
    ascending=False
)
# Out:
# Customer Lname                   0.004432
# Customer Zipcode                 0.001662
# Type                             0.000000
# Order Item Profit Ratio          0.000000
# Order City                       0.000000
# Order Country                    0.000000
# Order Customer Id                0.000000
# Order Item Discount              0.000000
# Order Item Discount Rate         0.000000
# Order Item Product Price         0.000000
# Order Item Quantity              0.000000
# Longitude                        0.000000
# Sales                            0.000000
# Order Item Total                 0.000000
# Order Profit Per Order           0.000000
# Order Region                     0.000000
# Order State                      0.000000
# Order Status                     0.000000
# Product Name                     0.000000
# Product Price                    0.000000
# Market                           0.000000
# Latitude                         0.000000
# ...

# %% [raw]
# Duplicate records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [raw]
# statistical summary

# %%
df.describe().T
# Out:
#                                   count          mean           std  \
# Days for shipping (real)       180519.0      3.497654      1.623722
# Days for shipment (scheduled)  180519.0      2.931847      1.374449
# Benefit per order              180519.0     21.974989    104.433526
# Sales per customer             180519.0    183.107607    120.043668
# Late_delivery_risk             180519.0      0.548291      0.497664
# Category Id                    180519.0     31.851451     15.640064
# Customer Id                    180519.0   6691.379495   4162.918106
# Customer Zipcode               180516.0  35921.126914  37542.461122
# Department Id                  180519.0      5.443460      1.629246
# Latitude                       180519.0     29.719955      9.813646
# Longitude                      180519.0    -84.915675     21.433241
# Order Customer Id              180519.0   6691.379495   4162.918106
# Order Item Discount            180519.0     20.664741     21.800901
# ...

# %% [raw]
# categorical columns

# %%
df.describe(include="object").T
# Out:
#                    count unique                               top    freq
# Type              180519      4                             DEBIT   69295
# Delivery Status   180519      4                     Late delivery   98977
# Category Name     180519     50                            Cleats   24551
# Customer City     180519    563                            Caguas   66770
# Customer Country  180519      2                           EE. UU.  111146
# Customer Fname    180519    782                              Mary   65150
# Customer Lname    180511   1109                             Smith   64104
# Customer Segment  180519      3                          Consumer   93504
# Customer State    180519     46                                PR   69373
# Customer Street   180519   7458           9126 Wishing Expressway     122
# Department Name   180519     11                          Fan Shop   66861
# Market            180519      5                             LATAM   51594
# ...

# %% [raw]
# Unique values

# %%
df["Customer Segment"].unique()
# Out:
# array(['Consumer', 'Home Office', 'Corporate'], dtype=object)

# %%
df["Market"].unique()
# Out:
# array(['Pacific Asia', 'LATAM', 'USCA', 'Europe', 'Africa'], dtype=object)

# %%
df["Category Name"].unique()
# Out:
# array(['Cardio Equipment', 'Shop By Sport', 'Water Sports',
#        "Women's Apparel", 'Camping & Hiking', 'Indoor/Outdoor Games',
#        'Fishing', 'Cleats', 'Electronics', "Men's Footwear",
#        'Accessories', 'Fitness Accessories', 'Trade-In',
#        'Baseball & Softball', 'Golf Gloves', "Men's Golf Clubs",
#        'Golf Balls', 'Hockey', 'Golf Shoes', 'Boxing & MMA',
#        'Golf Apparel', "Girls' Apparel", 'As Seen on  TV!', 'Lacrosse',
#        'Tennis & Racquet', "Kids' Golf Clubs", 'Strength Training',
#        'Soccer', 'Golf Bags & Carts', 'Hunting & Shooting',
#        "Women's Golf Clubs", 'Basketball', 'Books ', 'Baby ', 'CDs ',
#        'Cameras ', "Children's Clothing", 'Computers',
#        'Consumer Electronics', 'Crafts', 'DVDs', 'Garden',
#        'Health and Beauty', "Men's Clothing", 'Music', 'Pet Supplies',
#        'Sporting Goods', 'Toys', 'Video Games', "Women's Clothing"],
#       dtype=object)

# %%
df["Shipping Mode"].unique()
# Out:
# array(['Standard Class', 'Same Day', 'First Class', 'Second Class'],
#       dtype=object)

# %%
df["Order Status"].unique()
# Out:
# array(['COMPLETE', 'ON_HOLD', 'PENDING_PAYMENT', 'PENDING', 'CLOSED',
#        'PROCESSING', 'PAYMENT_REVIEW', 'SUSPECTED_FRAUD', 'CANCELED'],
#       dtype=object)

# %% [raw]
# Revenue validation

# %%
df["Sales"].describe()
# Out:
# count    180519.000000
# mean        203.772092
# std         132.273075
# min           9.990000
# 25%         119.980000
# 50%         199.920000
# 75%         299.950000
# max        1999.990000
# Name: Sales, dtype: float64

# %%
(df["Sales"] < 0).sum()
# Out:
# np.int64(0)

# %%
(df["Sales"] == 0).sum()
# Out:
# np.int64(0)

# %% [raw]
# Profit validation

# %%
df["Order Profit Per Order"].describe()
# Out:
# count    180519.000000
# mean         21.974989
# std         104.433526
# min       -4274.980000
# 25%           7.000000
# 50%          31.520000
# 75%          64.800000
# max         911.800000
# Name: Order Profit Per Order, dtype: float64

# %%
(
    df["Order Profit Per Order"] < 0
).sum()
# Out:
# np.int64(33784)

# %% [raw]
# Discount Validation

# %%
df["Order Item Discount Rate"].describe()
# Out:
# count    180519.000000
# mean          0.101668
# std           0.070415
# min           0.000000
# 25%           0.040000
# 50%           0.100000
# 75%           0.160000
# max           0.250000
# Name: Order Item Discount Rate, dtype: float64

# %%
df["Order Item Discount Rate"].max()
# Out:
# 0.25

# %%
df["Order Item Discount Rate"].min()
# Out:
# 0.0

# %% [raw]
# Business snapshots

# %% [raw]
# total revenue

# %%
total_revenue = df["Sales"].sum()

print(f"Total Revenue: ${total_revenue:,.2f}")
# Out:
# Total Revenue: $36,784,734.31

# %% [raw]
# total profit

# %%
total_profit = df["Order Profit Per Order"].sum()

print(f"Total Profit: ${total_profit:,.2f}")
# Out:
# Total Profit: $3,966,902.97

# %% [raw]
# Profit margin

# %%
profit_margin = (
    total_profit /
    total_revenue
) * 100

print(
    f"Profit Margin: {profit_margin:.2f}%"
)
# Out:
# Profit Margin: 10.78%

# %% [raw]
# Total customers

# %%
df["Customer Id"].nunique()
# Out:
# 20652

# %% [raw]
# Total products

# %%
df["Product Name"].nunique()
# Out:
# 118

# %% [raw]
# Total markets

# %%
df["Market"].nunique()
# Out:
# 5

# %% [markdown]
# # Initial Findings
#
# ## Dataset Overview
#
# 1. Dataset contains 180,519 rows and 40 columns.
#
# 2. Total Revenue = $36.78 Million
#
# 3. Total Profit = $3.97 Million
#
# 4. Overall Profit Margin = 10.78%
#
# 5. Total Customers = 20,652
#
# 6. Dataset contains multiple product categories across global markets and regions.
#
# ---
#
# ## Data Quality Assessment
#
# 7. Missing Values Found In:
#    - Customer Lname
#    - Customer Zipcode
#    - Product Description (if available in dataset)
#    - Few location-related fields
#    - Detailed cleaning required in next phase
#
# 8. Duplicate Records:
#    - No significant duplicate records detected
#    - Further validation required during cleaning
#
# 9. Loss-Making Orders:
#    - A considerable number of orders have negative profit values
#    - These records are business-relevant and should not be removed
#    - They will be analyzed to identify margin erosion drivers
#
# ---
#
# ## Business Understanding
#
# 10. Key Business Objectives:
#     - Identify high-value customers
#     - Detect loss-making customers
#     - Evaluate product and category profitability
#     - Measure discount impact on margins
#     - Compare profitability across markets and regions
#     - Build a profitability prediction model
#
# ---
#
# ## Initial Business Insights
#
# 11. Revenue and profit are not directly proportional.
#     Several customers and products generate high sales but low profit.
#
# 12. Discounting appears to be a major factor affecting profitability.
#
# 13. Profitability varies significantly across categories, customers, and markets.
#
# 14. The dataset is suitable for:
#
#     - Customer Profitability Analysis
#     - Product & Category Profitability Analysis
#     - Discount Impact Diagnostics
#     - Market & Regional Performance Analysis
#     - Customer Segmentation
#     - Profitability Prediction Modeling
#     - Interactive Streamlit Dashboard Development
